# %%
import spotipy 
import bs4
import requests
import pandas as pd

# %%
import sys
sys.path.append('../../')
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %% [markdown]
# import sys
# sys.path.append('../../')
# import config
# import spotipy
# import json
# from spotipy.oauth2 import SpotifyClientCredentials
# import pprint
#
# sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
#                                                            client_secret= config.client_secret))

# %% [markdown]
# ## Checking songs

# %%
results = sp.search(q="Lose yoursself",limit=1,market="GB")
results

# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# .audio_features([URL|URI|ID])
#json_results = json.dumps(results, ensure_ascii=True)

#results['tracks']['items'][0]['external_urls']["spotify"]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lose+yoursself&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#      'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#      'id': '1rfORa9iYmocEsnnZGMVC4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#        'width': 64}],
#      'name': 'Just Lose It',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 322226,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#     'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#     'id': '1v7L65Lzy0j0vdpRjJewt1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f467be5b4e9eeba6c5a7d563d253f50bce56b9cd?cid=bb8e1cb1920440889a304cd5db0dec15',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Lose+yoursself&type=track&market=GB&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
results["tracks"]["next"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=3&limit=3'

# %%
# pprint.pprint(results)

# %%
# results['tracks']["items"][0].keys()

# %%
# results['tracks']['items'][0]

# %%
# results['tracks']['items'][0]['id']

# %%
# results['tracks']['items'][0]['external_urls'] this is for full url

# %%
# for item in results['tracks']['items']:
#     print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))

# %%
song = sp.search(q="Bad Guy", limit=50,market="GB")

# %%
# song["tracks"]["items"][2]

# %%
#pprint.pprint(song['tracks']['items'][0]['uri'])
# song["tracks"]["items"][0]["uri"]

# output: 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks), for speed & remember to put in a for loop to downloads songs in next link
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=1
# The song's info is contained in:  [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'}, 'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4', 'id': '1rfORa9iYmocEsnnZGMVC4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec', 'width': 64}], 'name': 'Just Lose It', 'release_date': '2004-01-01', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'disc_number': 1, 'duration_ms': 322226, 'explicit': True, 'external_ids': {'isrc': 'USIR10211559'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'}, 'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1', 'id': '1v7L65Lzy0j0vdpRjJewt1', 'is_local': False, 'is_playable': True, 'name': 'Lose Yourself - From "8 Mile" Soundtrack', 'popularity': 77, 'preview_url': 'https://p.scdn.co/mp3-preview/f467be5b4e9eeba6c5a7d563d253f50bce56b9cd?cid=bb8e1cb1920440889a304cd5db0dec15', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}]
# The limit of the query we've made is:  1
# The next page if any:  https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=1&limit=1
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  1000

# %% [markdown]
# ## Checking albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print("****************\n")
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("****************\n")
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print("****************\n")
print("The album name is: ",results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
# Out:
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'}, 'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4', 'id': '1rfORa9iYmocEsnnZGMVC4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec', 'width': 64}], 'name': 'Just Lose It', 'release_date': '2004-01-01', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'}
# ****************
#
# ['album_type', 'artists', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# ****************
#
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}]
# ****************
#
# The album ID is:  1rfORa9iYmocEsnnZGMVC4
# ****************
#
# The album name is:  Just Lose It

# %% [markdown]
# ## Other Info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'

# %% [markdown]
# ## Embeded track player

# %% [markdown]
# {'spotify': https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"
track_id= '3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id+"?utm_source=generator",
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# spotify:track:3hgl7EQwTutSm6PESsB7gZ
# or get the embedded url from spotify
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3hgl7EQwTutSm6PESsB7gZ?utm_source=generator?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song("3hgl7EQwTutSm6PESsB7gZ")
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3hgl7EQwTutSm6PESsB7gZ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Getting the Audio feature of a song

# %%
track_id = results["tracks"]["items"][0]["id"]

# %%
sp.audio_features(results["tracks"]["items"][0]["id"] )
# key?, mode?, id?, uri?, ref? url?, duration? type are irrelevant
# Out:
# [{'danceability': 0.686,
#   'energy': 0.735,
#   'key': 2,
#   'loudness': -4.616,
#   'mode': 1,
#   'speechiness': 0.264,
#   'acousticness': 0.00921,
#   'instrumentalness': 0.00066,
#   'liveness': 0.342,
#   'valence': 0.0596,
#   'tempo': 171.355,
#   'type': 'audio_features',
#   'id': '1v7L65Lzy0j0vdpRjJewt1',
#   'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1',
#   'track_href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1v7L65Lzy0j0vdpRjJewt1',
#   'duration_ms': 322227,
#   'time_signature': 4}]

# %%
## example of bethoven track
sp.audio_features("1Y25uib0Cu5kYTtNuRqyRU")
# Out:
# [{'danceability': 0.403,
#   'energy': 0.171,
#   'key': 5,
#   'loudness': -21.561,
#   'mode': 0,
#   'speechiness': 0.0359,
#   'acousticness': 0.991,
#   'instrumentalness': 0.906,
#   'liveness': 0.0809,
#   'valence': 0.14,
#   'tempo': 98.886,
#   'type': 'audio_features',
#   'id': '1Y25uib0Cu5kYTtNuRqyRU',
#   'uri': 'spotify:track:1Y25uib0Cu5kYTtNuRqyRU',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Y25uib0Cu5kYTtNuRqyRU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y25uib0Cu5kYTtNuRqyRU',
#   'duration_ms': 271587,
#   'time_signature': 4}]

# %% [markdown]
# ## building Data frame of audio features

# %%
sp.audio_features(song["tracks"]["items"][0]["uri"])
#bad guy/ billie eilish
# Out:
# [{'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '2Fxmhks0bxGSBdJ92vM42m',
#   'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#   'duration_ms': 194088,
#   'time_signature': 4}]

# %%
len(song["tracks"]["items"])
# Out:
# 50

# %%
#my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

list_of_songs=[]
for index in range(0,len(song["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
df=pd.DataFrame(list_of_songs)    
df=df[["danceability","energy",'key',"loudness",'mode', "speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.701  0.4250    7   -10.965     1       0.3750      0.328000
# 1          0.670  0.4530    0   -11.265     1       0.2950      0.256000
# 2          0.612  0.7970    1    -3.648     1       0.4480      0.064000
# 3          0.701  0.4250    7   -10.965     1       0.3750      0.328000
# 4          0.811  0.7480    1   -10.298     1       0.0682      0.553000
# 5          0.670  0.4530    0   -11.265     1       0.2950      0.252000
# 6          0.695  0.7790    2    -5.975     1       0.2570      0.196000
# 7          0.698  0.3230    5    -9.980     1       0.1780      0.914000
# 8          0.582  0.8290    2    -5.688     1       0.0465      0.000517
# 9          0.563  0.8140    7    -4.219     0       0.0558      0.009830
# 10         0.670  0.4530    0   -11.265     1       0.2950      0.256000
# 11         0.474  0.9480    3    -2.592     1       0.1220      0.022300
# 12         0.801  0.6850    0    -5.515     0       0.0656      0.420000
# 13         0.698  0.4290    0    -9.246     0       0.0416      0.148000
# 14         0.643  0.7860    0    -3.976     1       0.0302      0.002550
# 15         0.736  0.4680    3    -8.572     0       0.1950      0.110000
# 16         0.830  0.4050    1    -8.484     1       0.4110      0.015800
# 17         0.758  0.2940    9    -9.113     0       0.0459      0.829000
# 18         0.612  0.7970    1    -3.648     1       0.4480      0.064000
# 19         0.824  0.7700    5    -7.281     0       0.1770      0.142000
# 20         0.847  0.4910    4    -8.025     0       0.4360      0.386000
# 21         0.722  0.7470    2    -3.483     1       0.0509      0.024900
# 22         0.785  0.6710   11    -7.108     0       0.0505      0.448000
# 23         0.526  0.6390    7    -6.140     1       0.1040      0.010600
# 24         0.619  0.0978    7   -18.509     0       0.0659      0.990000
# 25         0.800  0.9480    9    -2.340     0       0.1920      0.003210
# 26         0.697  0.4280    0    -9.252     0       0.0417      0.148000
# 27         0.531  0.0721    7   -20.598     0       0.0511      0.992000
# 28         0.775  0.4310    2   -17.153     1       0.3580      0.576000
# 29         0.575  0.8430    2    -4.402     1       0.0518      0.000743
# 30         0.505  0.6980    6    -7.559     0       0.0424      0.000930
# 31         0.677  0.8330    5    -6.286     0       0.0821      0.000300
# 32         0.695  0.7790    2    -5.975     1       0.2570      0.196000
# 33         0.604  0.5640    7    -6.875     1       0.2400      0.031600
# 34         0.945  0.8580    7   -10.271     1       0.4040      0.052100
# 35         0.674  0.8890    7    -3.039     0       0.3580      0.154000
# 36         0.720  0.4300    7   -10.942     1       0.3780      0.283000
# 37         0.692  0.6230    7   -11.172     1       0.2880      0.030300
# 38         0.864  0.7440    7    -7.629     0       0.0560      0.563000
# 39         0.730  0.7100    7    -3.976     1       0.0448      0.084100
# 40         0.764  0.4880    5    -6.017     1       0.0396      0.166000
# 41         0.700  0.6930    5    -5.092     1       0.2010      0.129000
# 42         0.516  0.5870    2    -5.756     1       0.0258      0.231000
# 43         0.608  0.7070    1    -7.930     1       0.1190      0.057200
# 44         0.869  0.6310    7    -5.985     0       0.0518      0.172000
# 45         0.730  0.7100    7    -3.976     1       0.0448      0.084200
# 46         0.546  0.4050    0   -12.652     1       0.1150      0.890000
# 47         0.612  0.5210   10    -7.137     1       0.0331      0.519000
# 48         0.677  0.7620    7    -5.994     0       0.0556      0.000915
# 49         0.790  0.8570    2    -7.556     1       0.0491      0.000179
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.130000    0.1000    0.562  135.128  2Fxmhks0bxGSBdJ92vM42m
# 1           0.327000    0.1170    0.685  135.047  1hNIiiqbjQ4TEu7ro9pEE1
# 2           0.000000    0.2570    0.358   81.086  3IaAYtmN8T0YIYVqnxNnVz
# 3           0.130000    0.1000    0.562  135.128  6GYfIYhM2uTsKZ50KEPk54
# 4           0.000000    0.1100    0.883  108.816  3gZoHbFt5W3HltDGcnbDrD
# 5           0.330000    0.1170    0.680  135.055  3yNZ5r3LKfdmjoS3gkhUCT
# 6           0.000000    0.1100    0.704  142.175  1VQKKey9XgeYOm6rd1Aje8
# 7           0.037000    0.0991    0.670  135.069  1qOsHMitiWT4Zhx9ICzmjW
# 8           0.000000    0.2660    0.867  130.969  0KqyBk4aVT88TEqBIC8mAP
# 9           0.043700    0.0732    0.796  140.615  0iM1Ioz4N4p7MU1DKyqsov
# 10          0.327000    0.1170    0.685  135.047  68lcSQzWNYALsEkqlq5eTK
# 11          0.000000    0.4300    0.611  146.460  78ML3F5Lz3KiNkpnFAaR3q
# 12          0.000000    0.1000    0.777  108.024  6O0yvfx7qeE16s0UyhxOVT
# 13          0.691000    0.1010    0.540  134.946  2FH0jT9o0mz71s7AtMkAa4
# 14          0.000000    0.0462    0.520  107.005  760frpppJAxqsVBuiOt1yL
# 15          0.000000    0.1070    0.417   80.505  5w4enr0FN8ZTwxmfnACz2f
# 16          0.000009    0.2410    0.188  147.070  5TvdhNXoHbeGeWtjCYhFuy
# 17          0.000009    0.0981    0.348  120.041  1zQ2PdP4hpA9gaWiaMMoJy
# 18          0.000000    0.2570    0.358   81.086  5SpWTzTFzy2UiZWaEWCHWn
# 19          0.000000    0.1120    0.327  119.887  408if5LwFlG8lsyYkSGjJn
# 20          0.000067    0.1190    0.623  139.947  7emJRAhUHhLtBtvzjDpjMC
# 21          0.000005    0.1970    0.343   95.866  4KVVy0GeXO03ni8Cv4SWk8
# 22          0.000018    0.2250    0.588  124.899  1O8BgvuH9SMVddb3MQINwp
# 23          0.000022    0.1200    0.717  135.012  3UCQwTclMnDYtS0uVjNTGO
# 24          0.926000    0.1100    0.183  104.804  1zXv69mtvZlCVNKcnutbp7
# 25          0.000000    0.0800    0.924  104.971  6ST6x5sSLYArqrh30p3KBs
# 26          0.668000    0.1010    0.523  134.954  4LzDR9ArSfr065cLQgpuba
# 27          0.928000    0.1090    0.131  125.962  1X7w76pP3ymtufU4svvLIv
# 28          0.000000    0.1900    0.651   90.989  39K3k1vI5UQKm2IBpsiGhv
# 29          0.000000    0.3150    0.843  130.982  5R4UtkoueIomI2z3Ei8B38
# 30          0.004020    0.2980    0.647  147.963  5lWZcRV1Mtmhc2RZ4FW2xF
# 31          0.000208    0.1220    0.409  135.015  12R0kO3aF9VsaOlGlb4j5L
# 32          0.000000    0.1100    0.704  142.175  7vLzU22xRA0pz9A8Ch1NNl
# 33          0.000005    0.5850    0.872  135.973  6tRLfrfy692qlbT2cECgQS
# 34          0.143000    0.0494    0.632  134.992  2uqN75iYEOcDQEtpCg65Ms
# 35          0.000000    0.3000    0.477  127.678  3Ns09BvC3CxkN3wYC6P6m4
# 36          0.114000    0.0989    0.533  121.945  5TAr9GfcQXXl6cwFfzvA6I
# 37          0.000001    0.0958    0.384  134.987  7ER1r3QQOPfjj3x1UCa5pq
# 38          0.139000    0.0998    0.771  135.042  4PzQW8dAwFW8p9g9UkeiWs
# 39          0.000000    0.3410    0.544  114.949  4g077yizjVdMB5HFl3rJRo
# 40          0.000000    0.0979    0.237  124.923  34LbYwWS8Vxr6dsdZ64OXd
# 41          0.000000    0.2320    0.475  146.109  4727RsuKMuY09HnC1ZD6yt
# 42          0.000000    0.1080    0.237   78.024  0otmxJEwq9JI1CidrcYEq4
# 43          0.000000    0.0881    0.264   81.983  66bfOuj9ki2cYWeUcgAkET
# 44          0.000009    0.0671    0.646  135.027  66wi6NRfwsula1n68bJEod
# 45          0.000000    0.3460    0.544  114.946  5XYNCCkYoFLegWZcQU9ecn
# 46          0.000000    0.1540    0.170   94.953  5MnmiNtrFIszeBHE5ocYcT
# 47          0.000000    0.1660    0.368   92.988  6BZuf8iLTI18rN8L8WarzL
# 48          0.381000    0.0966    0.736  135.989  22QpE67BB819wfq63IWWg8
# 49          0.541000    0.0383    0.747  125.011  6uGiIWcBzSYqO5ZGYk6lqE
#
#     duration_ms
# 0        194088
# 1        194840
# 2        434077
# 3        194088
# 4        136133
# 5        194840
# 6        221560
# 7        193227
# 8        197800
# 9        157832
# 10       194840
# 11       195373
# 12       152970
# 13       191975
# 14       189227
# 15       146773
# 16       169493
# 17       183241
# 18       434077
# 19       228500
# 20       192400
# 21       279133
# 22       159360
# 23       191806
# 24       141086
# 25       188817
# 26       191975
# 27       166625
# 28       227867
# 29       197613
# 30       108032
# 31       194055
# 32       221560
# 33       194062
# 34       152940
# 35       144316
# 36       194080
# 37       193361
# 38       173479
# 39       221253
# 40       213554
# 41       138082
# 42       225101
# 43       180000
# 44       167908
# 45       221253
# 46       182246
# 47       250000
# 48       163269
# 49       215040

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "7beGd4yYY1qpsBv6K3clFZ",market="GB")
# https://open.spotify.com/playlist/7beGd4yYY1qpsBv6K3clFZ

# %% [markdown]
# ## extracting a song from playlist

# %%
playlist["items"][0]
# Out:
# {'added_at': '2020-09-18T11:03:07Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qoh8oezhy6uxn8gd4vy7ddlty'},
#   'href': 'https://api.spotify.com/v1/users/qoh8oezhy6uxn8gd4vy7ddlty',
#   'id': 'qoh8oezhy6uxn8gd4vy7ddlty',
#   'type': 'user',
#   'uri': 'spotify:user:qoh8oezhy6uxn8gd4vy7ddlty'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6EVYTRG1drKdO8OnIQBeEj'},
#    'href': 'https://api.spotify.com/v1/albums/6EVYTRG1drKdO8OnIQBeEj',
#    'id': '6EVYTRG1drKdO8OnIQBeEj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273deec12a28d1e336c5052e9aa',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02deec12a28d1e336c5052e9aa',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851deec12a28d1e336c5052e9aa',
#      'width': 64}],
#    'name': 'My Everything (Deluxe)',
#    'release_date': '2014-08-25',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6EVYTRG1drKdO8OnIQBeEj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#     'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#     'id': '66CXWjxzNUsdJxJ2JdwvnR',
#     'name': 'Ariana Grande',
#     'type': 'artist',
#     'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#   'disc_number': 1,
#   'duration_ms': 233720,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71409739'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3hgl7EQwTutSm6PESsB7gZ'},
#   'href': 'https://api.spotify.com/v1/tracks/3hgl7EQwTutSm6PESsB7gZ',
#   'id': '3hgl7EQwTutSm6PESsB7gZ',
#   'is_local': False,
#   'is_playable': True,
#   'name': "You Don't Know Me",
#   'popularity': 48,
#   'preview_url': None,
#   'track': True,
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'},
#  'video_thumbnail': {'url': None}}

# %%
playlist["items"][0]["track"]["id"]
# Out:
# '3hgl7EQwTutSm6PESsB7gZ'

# %%
play_song(playlist["items"][0]["track"]["id"])
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3hgl7EQwTutSm6PESsB7gZ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  4514
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %% [markdown]
# ## Start Here

# %%
import spotipy 
import bs4
import requests
import pandas as pd

# %%
import sys
sys.path.append('../../')
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# small_playlist = ['0zkl7eKzuUit1QRPVKtga2','6hb6t3iN9EfZDZpSXDOgcc','37i9dQZF1DWWEJlAGA9gs0','1h0CEZCm6IbFTbxThn6Xcs','37i9dQZF1DWVFeEut75IAL','37i9dQZF1DX7dzHXrANAir']

# %%
small_playlist = ['1h0CEZCm6IbFTbxThn6Xcs']

# %%
# tracks=get_playlist_tracks("spotify", plist)

# %%
# len(tracks)
# Out:
# 10000

# %%
# tracks[51]

# %%
# test_0 = sp.audio_features(tracks[0]["track"]["id"])[0]
# print(test_0)

# %%
list_of_audio_features=[]
for plist in small_playlist:
    tracks=get_playlist_tracks("spotify", plist)
    for item in range(0, len(tracks)):
        try:
            
                if tracks[item]["track"] == None:
                    print(item)
                    pass #dont't do it
                else:
                    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0]) 
        except:
                print(item) #optional
                pass #(print + pass) OR just pass
        

# or tracks[item]["track"] == None or tracks[item] == None or tracks == None

# %%
# print(list_of_audio_features[96])

# %%
len(list_of_audio_features)
# Out:
# 185

# %%
# print(list_of_audio_features[0])

# %%
list_no_none = []
for item in list_of_audio_features:
    if item != None :
        list_no_none.append(item)

# list_no_none

# %%
df=pd.DataFrame(list_no_none)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#      danceability   energy  loudness  speechiness  acousticness  \
# 0           0.213  0.06560   -24.810       0.0467         0.992
# 1           0.330  0.00357   -33.142       0.0339         0.995
# 2           0.368  0.00363   -36.759       0.0350         0.993
# 3           0.320  0.00501   -33.366       0.0455         0.993
# 4           0.701  0.34100   -12.260       0.0418         0.499
# ..            ...      ...       ...          ...           ...
# 180         0.162  0.06820   -21.254       0.0393         0.989
# 181         0.489  0.01410   -23.312       0.0453         0.994
# 182         0.273  0.00516   -27.926       0.0397         0.994
# 183         0.130  0.08600   -21.920       0.0373         0.932
# 184         0.176  0.00600   -42.238       0.0384         0.899
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.969000    0.0699   0.0384   65.023  3U8Fx7zNTQrctytkj6Gqgd
# 1            0.953000    0.0989   0.1210  100.741  6MzbO6YS0M6tjwT93hjAl0
# 2            0.922000    0.1370   0.0850   69.363  1L4NadMj3Jj7YgGaikyhfr
# 3            0.919000    0.0618   0.0383   68.947  3hCPh4oVVjaM8tv9sFH8cx
# 4            0.903000    0.3590   0.1630  105.513  5xbuJuQsTVheVZvX2AJVIv
# ..                ...       ...      ...      ...                     ...
# 180          0.475000    0.1160   0.0358  144.568  2TOUdZaG9w8pbGVoH0GohP
# 181          0.898000    0.1090   0.2720  127.461  3SokfTeWt84ZeUenQUPzAX
# 182          0.900000    0.0955   0.1360   91.405  73cFlYu63RLX1qn9qzMXiJ
# 183          0.912000    0.1080   0.0375   90.223  3Sy6wgTNEp6vSgLs4EyXAf
# 184          0.000032    0.1050   0.0383   71.477  4wudbbceOZKjRlhTtbHvAs
#
#      duration_ms
# 0         150147
# 1         216213
# 2         254000
# 3         294960
# 4         151507
# ..           ...
# 180       228013
# 181       194667
# 182       176187
# 183       391160
# 184       636000
#
# [185 rows x 11 columns]

# %%
df.to_csv("./df_classical.csv")

# %%
END
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/thaopham/Documents/dev/m2lab_spotify.ipynb Cell 59 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/thaopham/Documents/dev/m2lab_spotify.ipynb#Y142sZmlsZQ%3D%3D?line=0'>1</a> END
#
# NameError: name 'END' is not defined

# %%
# Read CSV files from List

df_concat = pd.concat(map(pd.read_csv, ['df1.csv', 'df2.csv','df3.csv','df4.csv', 'df5.csv','df8.csv', 'df9.csv','df10.csv', 'df11.csv','df12.csv','df13.csv', 'df14.csv','df15.csv','df_official_longest.csv','df_classical.csv']))

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20368 entries, 0 to 184
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20368 non-null  int64
#  1   danceability      20368 non-null  float64
#  2   energy            20368 non-null  float64
#  3   loudness          20368 non-null  float64
#  4   speechiness       20368 non-null  float64
#  5   acousticness      20368 non-null  float64
#  6   instrumentalness  20368 non-null  float64
#  7   liveness          20368 non-null  float64
#  8   valence           20368 non-null  float64
#  9   tempo             20368 non-null  float64
#  10  id                20368 non-null  object
#  11  duration_ms       20368 non-null  int64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 2.0+ MB

# %%
df_concat.to_csv("./df_concat_20368.csv")

# %% [markdown]
# ## End Here

# %% [markdown]
# ## Extra useful functions

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
for index in range(0, 10):
    print(get_artists_from_track(tracks[index]['track']))
# Out:
# ['Hozier']
# ['Mike Posner', 'Gigamesh']
# ['Tyler, The Creator', 'Kali Uchis']
# ['Bastille']
# ['Shakira', 'Wyclef Jean']
# ['The Script', 'will.i.am']
# ['Otto Knows', 'Avicii']
# ['Selena Gomez']
# ['Taio Cruz']
# ['Mohombi']

# %%
tracks[0]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#     'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#     'id': '2FXC3k01G6Gw61bmprjgqS',
#     'name': 'Hozier',
#     'type': 'artist',
#     'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7HW03Zew4rnOhy5uwskRSz'},
#   'href': 'https://api.spotify.com/v1/albums/7HW03Zew4rnOhy5uwskRSz',
#   'id': '7HW03Zew4rnOhy5uwskRSz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736a452516b66b53f65a3e4b33',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026a452516b66b53f65a3e4b33',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516a452516b66b53f65a3e4b33',
#     'width': 64}],
#   'name': 'Hozier (Deluxe)',
#   'release_date': '2014-05-20',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:7HW03Zew4rnOhy5uwskRSz'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#    'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#    'id': '2FXC3k01G6Gw61bmprjgqS',
#    'name': 'Hozier',
#    'type': 'artist',
#    'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#  'disc_number': 1,
#  'duration_ms': 241688,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'IEACJ1300031'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3dYD57lRAUcMHufyqn9GcI'},
#  'href': 'https://api.spotify.com/v1/tracks/3dYD57lRAUcMHufyqn9GcI',
#  'id': '3dYD57lRAUcMHufyqn9GcI',
#  'is_local': False,
#  'is_playable': True,
#  'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7dS5EaCoMnN7DzlpT6aRn2'},
#   'href': 'https://api.spotify.com/v1/tracks/7dS5EaCoMnN7DzlpT6aRn2',
#   'id': '7dS5EaCoMnN7DzlpT6aRn2',
#   'type': 'track',
#   'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2'},
#  'name': 'Take Me To Church',
#  'popularity': 79,
#  'preview_url': None,
#  'track': True,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:3dYD57lRAUcMHufyqn9GcI'}

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ['',
#  'M-Fuse',
#  'The Magician',
#  'K-391',
#  'Nost3 & Protro',
#  'N.E.R.D',
#  'DJ Frank E',
#  'Ava Max',
#  'Swell',
#  'Kerli',
#  'Elastinen',
#  'Tai Verdes',
#  'ILARI',
#  'Kygo',
#  'DaBaby',
#  'Miguel',
#  'A$AP Ferg',
#  'Alec Benjamin',
#  'Foster The People',
#  'Jonihey',
#  'Charlie Puth',
#  'Anna Puu',
#  'Alyson Stoner',
#  'Annika Eklund',
#  'EDEN',
#  'Marc Anthony',
#  'ALMA',
#  'Pikku G',
#  'Sigala',
#  'Hippie Sabotage',
#  'Fatman Scoop',
#  'Mind Vortex',
#  'D.O.E.',
#  'Coolio',
#  'Arizona Zervas',
#  'Tim McMorris',
#  'Majuri',
#  'Chimamanda Ngozi Adichie',
#  'Skip Marley',
#  'Raappana',
#  'DJ Katch',
#  'Aqua',
#  'Zachary Knowles',
#  'Example',
#  'SoMo',
#  'Väinöväinö',
#  'BROCKHAMPTON',
#  'Tiny Tim',
#  'Ellinoora',
#  'A Boogie Wit da Hoodie',
#  'TOTO',
#  'Florence + The Machine',
#  'Alexandra Stan',
#  'Eazy-E',
#  'Handsome Luke',
#  'lil aaron',
#  'Jamelia',
#  'Kid Crave',
#  'CJ',
#  'Rick Ross',
#  'Poo Bear',
#  'Duncan Laurence',
#  'Conan Gray',
#  'Nytrix',
#  'Tomppabeats',
#  'Vege',
#  'Papa Roach',
#  'Wolfpack',
#  'Alan Walker',
#  'Frank Ocean',
#  'Migos',
#  'Los Del Rio',
#  'Cheek',
#  'All Time Low',
#  'J. Cole',
#  'China Anne McClain',
#  'Kendrick Lamar',
#  'Darius & Finlay',
#  'Alfons',
#  'WILLOW',
#  'Sean Paul',
#  'ILOVEMAKONNEN',
#  'Tears For Fears',
#  'Sultan',
#  'Madison Beer',
#  'BeatKing',
#  'Lonely God',
#  'Verdine White',
#  'Bang For The Buck',
#  'Lil Wayne',
#  'Meiju Suvas',
#  'Daya',
#  'Lykke Li',
#  'Johanna Kurkela',
#  'Mary Lambert',
#  'Eduardo Nascimento',
#  '3OH!3',
#  'Preme',
#  'Samuli Edelmann',
#  'Death Cab for Cutie',
#  'Gesaffelstein',
#  'Bizi',
#  'William Singe',
#  'Reset',
#  'Foxes',
#  'Party Favor',
#  'Dante Leon',
#  'Ski Mask The Slump God',
#  'M83',
#  'Sara Bareilles',
#  'Paramore',
#  'Lovely Peaches',
#  'Leven Kali',
#  'Raaban',
#  'G.R.L.',
#  'Matchbox Twenty',
#  'Survivor',
#  'Michael Schulte',
#  'The Throne',
#  'Zoé',
#  'Gus Dapperton',
#  'Quavo',
#  'Edward Maya',
#  'BigKlit',
#  'Bon Jovi',
#  'Good Charlotte',
#  'Britney Spears',
#  'Sneazzy',
#  'Mariska & Pahat Sudet',
#  'Bryan Rice',
#  'iLOVEFRiDAY',
#  'Alex Joseph',
#  'mayklove',
#  'Rejjie Snow',
#  'Jon Bellion',
#  'Kaoma',
#  'Boyzone',
#  'Adizi X Typelik',
#  'Santana',
#  'Kim Herold',
#  'Black Eyed Peas',
#  'Normani',
#  'No Doubt',
#  'Roy English',
#  'Kraantje Pappie',
#  'The Game',
#  'Jonne Aaron',
#  'Conor Maynard',
#  'Sturm und Drang',
#  'Lil Tecca',
#  'Lil Gnar',
#  'Hayley Williams',
#  'salem ilese',
#  'Robin og Bugge',
#  'Mitch Crown',
#  'Niall Horan',
#  'The Moose',
#  'Paperi T',
#  'Emily Osment',
#  '2Pac',
#  'Ilkka Vainio',
#  'Lauri Tähkä',
#  'Danelle Sandoval',
#  'Kwabs',
#  'The All-American Rejects',
#  'LL COOL J',
#  'H.E.R.',
#  '5 Seconds of Summer',
#  'Anastacia',
#  'RAYE',
#  'Jesse Markin',
#  'Ola',
#  'Team 10',
#  'Seeb',
#  'John Legend',
#  'Litfranse',
#  'SAYGRACE',
#  'Saimaa',
#  'W&W',
#  'Danny Avila',
#  'Sada Baby',
#  'Lauri Haav',
#  'Death Grips',
#  'Styles P',
#  'Zeeba',
#  'Gotye',
#  'Funk Wav',
#  'James Blake',
#  'Mikael Gabriel',
#  'Halestone',
#  'JJani',
#  'Armin van Buuren',
#  'Ulpu',
#  'SLS',
#  'Hot Chelle Rae',
#  'SZA',
#  'Daler Mehndi',
#  'P. Moody',
#  'Hellberg',
#  'Jamie Lynn Spears',
#  'Thomas Rhett',
#  'Nelly',
#  'Pariisin Kevät',
#  'Joey Bada$$',
#  'Anna of the North',
#  'william',
#  'Katri Helena',
#  'Sliki & Hamuelos',
#  'One Direction',
#  'Aloe Blacc',
#  'KANDY',
#  'Andero & Nectum',
#  'Altis',
#  'LP',
#  'Asa',
#  'MC Hammer',
#  'Alina Baraz',
#  'Shinedown',
#  'Stunna 4 Vegas',
#  'JUVENILE',
#  'Bosson',
#  'Lene Marlin',
#  'Ty Dolla $ign',
#  'Riki Sorsa',
#  'Matte Caliste',
#  'Remy Boyz',
#  'Skylar Grey',
#  'Sir Mix-A-Lot',
#  'Herrat',
#  'Jeremy Folderol',
#  'Lucas',
#  'Fleur East',
#  'KajO',
#  'The Mistery',
#  'Post Malone',
#  'Cameron Kuwada',
#  'Kristiina Brask',
#  'Joji',
#  'Sebastian Ingrosso',
#  'Everlast',
#  'Eric Turner',
#  'Pekka Kuusisto',
#  'Fools Garden',
#  'Waka Flocka Flame',
#  'Zion & Lennox',
#  'Quality Control',
#  'Busy Signal',
#  'Cameron Boyce',
#  'Eiffel 65',
#  'Ryanning',
#  'Sunrise Avenue',
#  'Paul McCartney',
#  'Camila Cabello',
#  'Dingo',
#  'Katy B',
#  'Kristinia DeBarge',
#  'Hot Shade',
#  'FKi 1st',
#  'Kuningas Pähkinä & Setä Tamu',
#  'Aurora',
#  'Kyler England',
#  'Pink',
#  'Summer Walker',
#  'Shakira',
#  'Dido',
#  'Johnta Austin',
#  'JACKBOYS',
#  'VIIVI',
#  "I'Dees",
#  'J Balvin',
#  'WanMor',
#  'The Living Tombstone',
#  'PnB Rock',
#  'The Chordettes',
#  'Like Mike',
#  'Chase Atlantic',
#  'Chief Keef',
#  'gnash',
#  'Marc E. Bassy',
#  'Meja',
#  'Duki',
#  'Tierra Whack',
#  'Rick Rock',
#  'Getter Jaani',
#  'Filip Jenven',
#  'Fabe',
#  'O.C',
#  'U96',
#  'SEUNGRI',
#  'DJ Martin ElectroSpin',
#  'Infinity',
#  'Matoma',
#  'Jennifer Lawrence',
#  'Buddy',
#  'Rich Brian',
#  'Ricky Martin',
#  'Flo Rida',
#  'TUULI',
#  'Mac Beez',
#  'Blind Channel',
#  'Major Lazer',
#  'James Arthur',
#  'JoJo',
#  "Why Don't We",
#  'NLE Choppa',
#  'Ice Cube',
#  'Calpurnia',
#  'Teqkoi',
#  'Lindsay Lohan',
#  'Troy',
#  'Timbaland',
#  'G Herbo',
#  'LIOHN',
#  'Happoradio',
#  'Bizzey',
#  'Say Lou Lou',
#  'beabadoobee',
#  'RH Music',
#  'Jabba',
#  "Waldo's People",
#  'Archie Cruz',
#  'Las Ketchup',
#  'Benjamin Ingrosso',
#  'Jaakko Laitinen',
#  'Sampha',
#  'Daniel Caesar',
#  'Emeni',
#  'Halestorm',
#  'Olivia Rodrigo',
#  'Tory Lanez',
#  'Baby Keem',
#  'Little Big',
#  'DJ White Shadow',
#  'Wham!',
#  'Axel Kala',
#  'John Gallagher Jr.',
#  'Edwyn Collins',
#  'SANNI',
#  'Ylvis',
#  'TRAQULA',
#  'Carrie Underwood',
#  'Juju',
#  'Freedom Williams',
#  'Cheat Codes',
#  'Fatboy L',
#  'Milky Chance',
#  '90s allstars',
#  'Teriyaki Boyz',
#  'BACALL',
#  'Emila',
#  'Tay Money',
#  'Sideshow',
#  'Popeda',
#  'Musta Barbaari',
#  'Far East Movement',
#  'Rebourne',
#  'Laurell',
#  'ZaeHD & CEO',
#  'JR Serpent',
#  'Zaytoven',
#  'Walt Ribeiro',
#  'Bonnie Tyler',
#  'Teflon Brothers',
#  'Lucenzo',
#  'Piso 21',
#  'Titta',
#  'Riff Raff',
#  'L.V.',
#  'Sum 41',
#  'Selena Gomez & The Scene',
#  'fun.',
#  'Jordin Sparks',
#  'BIA',
#  'Saweetie',
#  'Dirty Disco Youth',
#  'Devon Baldwin',
#  'Anderson .Paak',
#  '$NOT',
#  'Capital Cities',
#  'Bubba Sparxxx',
#  'Fuse ODG',
#  'Clean Bandit',
#  'Gromee',
#  'Jay Park',
#  'Jason Mraz',
#  'The Kid LAROI',
#  'VASSY',
#  'Yolanda Be Cool',
#  'Ironine',
#  'Neljänsuora',
#  'Leyla Blue',
#  'Rune RK',
#  'Ugly God',
#  'Mike Taylor',
#  'Boyat',
#  'Tham Sway',
#  'Goodboys',
#  'Kamaiyah',
#  'Silentó',
#  'Mr. 305',
#  'Pasi ja Anssi',
#  'Yade Lauren',
#  'Ryos',
#  'Kacy Hill',
#  'Junge Junge',
#  'Big Time Rush',
#  'Crystal Castles',
#  'The-Dream',
#  'A.G.',
#  'Are',
#  'Slim Jxmmi',
#  'Jay Prince',
#  'Kenny Loggins',
#  'Doe Boy',
#  'Ruma',
#  'Veela',
#  'Wiley',
#  'La Cream',
#  'Asian Doll',
#  'Ellie Goulding',
#  'Erin',
#  'Treyy G',
#  'Firebeatz',
#  'Internet Money',
#  'Jonas Vogel',
#  'NF',
#  'Mike Cervello',
#  'Pharrell Williams',
#  'Mr. President',
#  'J. Karjalainen Yhtyeineen',
#  'J. Karjalainen & Mustat Lasit',
#  'Rodríguez',
#  'Good Times Ahead',
#  'Justin Stone',
#  'KJ Apa',
#  'PUBLIC',
#  'Twenty One Pilots',
#  'Shapov',
#  '3 Doors Down',
#  'Travie McCoy',
#  'Gettomasa',
#  'Mannie Fresh',
#  'Hugh Jackman',
#  'TIPPA',
#  'Laidback Luke',
#  'Yetmir',
#  'Culture Beat',
#  'SONNY',
#  'Riverdale Cast',
#  'Banx & Ranx',
#  'Eldis',
#  'Indiiana',
#  'Mvd Jeyson',
#  'Ezkimo',
#  'Christina Aguilera',
#  'Joel Adams',
#  'The Cardigans',
#  'Pusha T',
#  'ZAYN',
#  'Martin Jensen',
#  'Kovee',
#  'Denmark + Winter',
#  'Juha Tapio',
#  'BENEE',
#  'Magnace',
#  'Mesto',
#  'Bonn',
#  'Rat City',
#  'Luh Kel',
#  'Stormzy',
#  'Riva Starr',
#  'DMX',
#  'Jack Joseph Puig',
#  'Kiana Ledé',
#  'Jare',
#  'Jay Alvarrez',
#  'Lady Leshurr',
#  'Mýa',
#  'Mon DJ',
#  'Grace Phipps',
#  'Joseph',
#  'Bridgit Mendler',
#  'ILLENIUM',
#  'The Notorious B.I.G.',
#  'Style of Eye',
#  'Kesha',
#  'Game of Thrones',
#  'Arron',
#  'Jhayco',
#  'Passenger',
#  'Grouplove',
#  'Desiigner',
#  'Tohtori Getto',
#  'Descemer Bueno',
#  'Rich Homie Quan',
#  'Tim Bergling',
#  'Unlike Pluto feat. Joanna Jones',
#  'TIX',
#  'Ghostemane',
#  'Lenka',
#  'Katy Perry',
#  'benny blanco',
#  'Lil Rain',
#  'Penelope Scott',
#  'Bobby Helms',
#  'Günther',
#  'Pop Smoke',
#  'mansionz',
#  'Lakko',
#  'Hendersin',
#  'Kacey Musgraves',
#  'Mark McCabe',
#  'Bruno Mars',
#  'Sound Of Legend',
#  'Evang',
#  'Nopsajalka',
#  'Fall Out Boy',
#  'Siine',
#  'Leevi and the leavings',
#  'Marcus Schössow',
#  'Ed Sheeran',
#  'blackbear',
#  'Gia Koka',
#  'Rivers Cuomo',
#  'Ayo & Teo',
#  'Waterparks',
#  'Luniz',
#  'YoungBoy Never Broke Again',
#  'DEV',
#  'Thomas Jack',
#  'James Brown',
#  'Rachel Platten',
#  'Lakim',
#  'Sabi',
#  'Mr. Probz',
#  'Lili Reinhart',
#  'Chrishan',
#  'FTampa',
#  'Hardwell',
#  'Martin Solveig',
#  'Maisie Peters',
#  'Ne-Yo',
#  'Tame Impala',
#  'Toby Fox',
#  'Disco Ensemble',
#  'The Him',
#  '90s Maniacs',
#  'Lil Baby',
#  'Konsta Original',
#  'J. Davi$',
#  'Tiktak',
#  'Brent Faiyaz',
#  'Michael Bolton',
#  'Juelz Santana',
#  'Likanen Etelä',
#  'The Naked And Famous',
#  'The Neighbourhood',
#  'My Chemical Romance',
#  'Mandi',
#  'Captain Cuts',
#  'Lily Allen',
#  'Pet Shop Boys',
#  'Dzeko',
#  'CMC$',
#  'Pale Waves',
#  'Oh Wonder',
#  'Aikakone',
#  'Gusttavo Lima',
#  'Wynter Gordon',
#  'IDOLS-Finalistit 2007',
#  'Grits',
#  'Young Roc',
#  'Travis Barker',
#  'Sami Hedberg',
#  'Mellen Gi',
#  'Mr. Collipark',
#  'Slugga Black',
#  'Sweet Baby May',
#  'Ali Gatie',
#  'lovelytheband',
#  'Frances Forever',
#  'Niko Saarinen',
#  'Koffee',
#  'Rick Astley',
#  'Studio Killers',
#  'Mohombi',
#  'Moby',
#  'Tommi Läntinen',
#  'Julia Michaels',
#  'Rudimental',
#  'Larray',
#  'Tainy',
#  't.A.T.u.',
#  'Lil Uzi Vert',
#  'XAM',
#  'Dropgun',
#  'Sini Sabotage',
#  'Petri Nygård',
#  'NITESHIFT',
#  'Jared Lee',
#  'Third Party',
#  'Metro Boomin',
#  'Aksel Kankaanranta',
#  'Michael Constantino',
#  'Scooter',
#  'K-Slim',
#  'Emma Hewitt',
#  'Flume',
#  'alt-J',
#  'Mac Miller',
#  'Alexis Jordan',
#  'Jess Glynne',
#  'Friday Pilots Club',
#  'Natalie Imbruglia',
#  'Nekfeu',
#  'The Script',
#  'D-Block & S-te-Fan',
#  'Mike Williams',
#  'Omar LinX',
#  'Vice',
#  'Dreamer Isioma',
#  'The Flint Chozen Choir',
#  'Jeffrey James',
#  'Amy Macdonald',
#  'GraphicMuzik',
#  'T.I.',
#  'White Town',
#  'Märkä-Simo',
#  'Toni Braxton',
#  'Kauniit & Uhkarohkeat',
#  'Justin Bieber',
#  'Fellatia Geisha',
#  'Maty Noyes',
#  'Aminé',
#  '50 Cent',
#  'Billy Marchiafava',
#  'Sam Fischer',
#  'Mr. Elämänpeli',
#  'Tiisu',
#  'Eurythmics',
#  'Ace of Base',
#  'Sharon',
#  'Mariska',
#  'Cuban Doll',
#  'Mase',
#  'Cutting Crew',
#  'Bazzi',
#  'Alice Deejay',
#  'E-Rotic',
#  'Tinashe',
#  'DJ DX',
#  'Macklemore',
#  'Haddaway',
#  'Lil Tjay',
#  'Breakbot',
#  'Grimes',
#  'Slim Mill',
#  'Maggie Lindemann',
#  'DJ Battlecat',
#  'Sueco',
#  'Joel Corry',
#  'Cosmo Sheldrake',
#  'Protoculture',
#  'Masterboy',
#  'Annie Lennox',
#  'Sista Prod',
#  'Kanye West',
#  'Kesh Kesh',
#  'Usher',
#  'Electric Light Orchestra',
#  'Tina Turner',
#  'Jed Will',
#  'Daniel Powter',
#  'Cimo Fränkel',
#  'Robyn',
#  'Michelle Williams',
#  'Crazy Town',
#  'MKTO',
#  'CamelPhat',
#  'Cazzu',
#  'Bryce',
#  'Miranda',
#  'YOUNGHEARTED',
#  'Shawn Mendes',
#  'Jake Reese',
#  'The Theme Song',
#  'Central Cee',
#  'The Cars',
#  'Versace Henrik',
#  'Zedd',
#  'T-Pain',
#  'Ryan Leslie',
#  'Ben Morfitt (SquidPhysics)',
#  'B.o.B',
#  'The Fray',
#  'Tuure Boelius',
#  'Sanjin',
#  'Sophia Somajo',
#  'Gasellit',
#  'Kodak Black',
#  'Pyhimys',
#  'Daft Punk',
#  'LCMDF',
#  'Juicy J',
#  'Matisyahu',
#  'Alicia Keys',
#  'Gracias',
#  'KVR',
#  'OG Ulla-Maija',
#  'Jessica Jarrell',
#  'The Ronettes',
#  'Toni Wirtanen',
#  'Baby Alice',
#  'Sibel',
#  'Promoting Sounds',
#  'Timmies',
#  'Rae Sremmurd',
#  'P-Lo',
#  'Eduardo Luzquiños',
#  'Morgan Page',
#  'Isaiah Firebrace',
#  'Halsey',
#  'Dimitri Vegas',
#  'Foo Fighters',
#  'Nicole Scherzinger',
#  'AlunaGeorge',
#  'Danny',
#  'Starkillers',
#  'U2',
#  'Eva Simons',
#  'Stefflon Don',
#  'Two Feet',
#  'Carnage',
#  'Bktherula',
#  'R. City',
#  'Wheeler Walker Jr.',
#  'D-wayne',
#  'Wasted Penguinz',
#  'Wintertime',
#  'Timo Pieni Huijaus',
#  'DJ KIMERA',
#  'Seekae',
#  '24kGoldn',
#  'Madchild',
#  'DRAM',
#  'Beats And Styles',
#  'JP Saxe',
#  'Seinabo Sey',
#  'Jacquie',
#  'Sairas T',
#  'Jason Derulo',
#  'Falling In Reverse',
#  'Beach Bunny',
#  'James Blunt',
#  'Supergrass',
#  'YBN Nahmir',
#  'SEB',
#  'Alissa Violet',
#  'Ca$his',
#  'Alex Vargas',
#  'MGMT',
#  'John Newman',
#  'Alesha Dixon',
#  'Ege Zulu',
#  'Eppu Normaali',
#  'La Santa Cecilia',
#  'jxdn',
#  'Marshmello',
#  '21 Savage',
#  'Estelle',
#  'Oliver Nelson',
#  'Running Touch',
#  'Pouya',
#  'Kris Kross Amsterdam',
#  'Vesa-Matti Loiri',
#  'Era Istrefi',
#  'Harry Fraud',
#  'Joznez',
#  'Y2K',
#  'The Oddictions',
#  'ZHU',
#  'Cyndi Lauper',
#  'Bobby Summer',
#  'Injury Reserve',
#  'Claire Rosinkranz',
#  'Vengaboys',
#  'MYKKA',
#  'SINAN',
#  'Black Sabbath',
#  'A$AP Rocky',
#  'Fleurie',
#  'Darude',
#  'James Newton Howard',
#  'Calvin Harris',
#  'Tre Coast',
#  'Mindless Self Indulgence',
#  'DJ Cassidy',
#  'Jimilian',
#  'Tyrone Briggs',
#  'Plustwo',
#  'Ryan Tedder',
#  'Nina Nesbitt',
#  'Gabrielle',
#  'Qulinez',
#  'Maija Vilkkumaa',
#  'Redrama',
#  'Sheck Wes',
#  'Queen',
#  'Sash!',
#  'LissA',
#  'MARINA',
#  'Cast of Shake It Up: Break It Down',
#  'Malo',
#  'Sammie',
#  'Priory',
#  'Tegan and Sara',
#  'Yung Berg',
#  'Ricky Montgomery',
#  'Oasis',
#  'Comethazine',
#  'Alex Newell',
#  'Sexmane',
#  'STEREO',
#  'Yves V',
#  'Tea',
#  'Jeezy',
#  'Thomas Doherty',
#  '*NSYNC',
#  'Jorja Smith',
#  'Lännen Liinein',
#  'Adam Levine',
#  'ROSALÍA',
#  'LIZ',
#  'Slash',
#  'American Authors',
#  'KiFi',
#  'Dorrough Music',
#  'Paleface',
#  'Mouhous',
#  'Eyedress',
#  'Ella Henderson',
#  'Bill Wurtz',
#  'Vory',
#  'Martti Vainaa',
#  'SAMUEL',
#  'Glass Animals',
#  'Malmö',
#  'Arttu Lindeman',
#  'Faul & Wad',
#  'Manian',
#  'CLMD',
#  'Sophie and the Giants',
#  "Olivia O'Brien",
#  'KYLE',
#  'Kylie Minogue',
#  'Diego Miranda',
#  'Savage Garden',
#  'Chris Willis',
#  'Gabriella Montez',
#  'Kranium',
#  'Arash',
#  'Sam Feldt',
#  'Kielijuhani',
#  'Antti Tuisku',
#  'Fat Joe',
#  '$wave',
#  'Aamupojat',
#  'Satin Circus',
#  'Millie B',
#  'Anna Eriksson',
#  'LMFAO',
#  'Dani Poppitt',
#  'Ilta',
#  'LLusion',
#  'Céline Dion',
#  'Jake Paul',
#  'Murcy',
#  'Gabry Ponte',
#  'Jay Hardway',
#  'Janelle Monáe',
#  'Molly',
#  'Digital Farm Animals',
#  'Megan Nicole',
#  '916frosty',
#  'Jukka Poika',
#  'Irfane',
#  'Jack Stauber',
#  'Keko Salata',
#  'Sasha Alex Sloan',
#  'Bobby Rock',
#  'Live for the weekend',
#  'Tyga',
#  'Kliff',
#  'Kenndog',
#  'Aly & AJ',
#  'Showtek & Justin Prime',
#  'Baby Tate',
#  'Byz',
#  'Mabel',
#  'Mikky Ekko',
#  'Journey',
#  'ABBA',
#  'BullySongs',
#  'Sigrid',
#  'LILMozart',
#  'Dean Martin',
#  'Big $tunt',
#  'Olly Murs',
#  'phem',
#  'Queen Key',
#  'Simple Plan',
#  'Borgore',
#  'Floorfilla',
#  'ARTY',
#  'JP Cooper',
#  'Jon-Jon',
#  'DJ Chose',
#  'Nicky Romero',
#  'Duke Dumont',
#  'Kim Petras',
#  'Redman',
#  'Peter Franzen',
#  'Master Blaster',
#  'Dragonette',
#  'Brennan Savage',
#  'Cozi Zuehlsdorff',
#  'Zendaya',
#  'Drenchill',
#  'Louis Tomlinson',
#  'Eevil Stöö',
#  'Swizz Beatz',
#  'Maluma',
#  'Sufjan Stevens',
#  'Logic',
#  'Westside Connection',
#  'Bananarama',
#  'Diplo',
#  'DJ BL3ND',
#  'Elena Coats',
#  'Cavallini',
#  'Skee-Lo',
#  'Faydee',
#  'Oliver Tree',
#  'Touko',
#  'Yung Pinch',
#  'Hannah Montana',
#  'Etta',
#  'Blasterjaxx',
#  'Cole Swindell',
#  'Jesse Kaikuranta',
#  'Tee Grizzley',
#  'Bobby Shmurda',
#  'Timi Lexikon',
#  'FINNEAS',
#  'Knife Party',
#  'Liam Payne',
#  'twocolors',
#  'Rixton',
#  'The Vamps',
#  'Luke Combs',
#  'Kelis',
#  'WALK THE MOON',
#  'Aries',
#  'Pras',
#  'Vedo',
#  'Sandro Cavazza',
#  'Timmy Trumpet',
#  'Jay Psar',
#  'Shawn Hook',
#  'Jamie Scott',
#  'Lupe Fiasco',
#  'PistePiste',
#  'Georgia Ku',
#  'Savage Ga$p',
#  'Childish Gambino',
#  'Dopebwoy',
#  'Ressu Redford',
#  'Lit',
#  "Rag'n'Bone Man",
#  "Auli'i Cravalho",
#  'The Pøssy Project',
#  'Don Toliver',
#  'Giveon',
#  'Lauren Bennett',
#  'Swae Lee',
#  'Kelly Clarkson',
#  'Pete Konemann',
#  'Polo G',
#  'Michael Bublé',
#  'Terri B!',
#  'Kuningasidea',
#  'FS Green',
#  'Lil Gotit',
#  'Gabriella',
#  'Lil Xan',
#  'Mike Posner',
#  'Florian Picasso',
#  'Cobra Starship',
#  'Kah-Lo',
#  'Maxx',
#  ...]

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# {'Alexandre Desplat',
#  'Alyx Ander',
#  'BTS',
#  'Banda Sinfónica da Polícia de Seguranca Pública',
#  'Banda de Música da Força Aérea',
#  'Coldplay',
#  'David Guetta',
#  'Galantis',
#  'Greta Bradman',
#  'Jon Hopkins',
#  'José Manuel Ferreira Brito',
#  'Ofenbach',
#  'Rihanna',
#  'Robin Schulz',
#  'SUGA',
#  'Seeb',
#  'Selena Gomez',
#  'Swedish House Mafia',
#  'The Chainsmokers',
#  'The String Family',
#  'Tiësto',
#  'Various Artists',
#  'Yotto',
#  'ZHU'}

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# 67135
